# %% [markdown]
# <a href="https://colab.research.google.com/github/palakchauhan21/Algorithm-lab-241b167/blob/main/Lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minimum Cost Spanning Tree
# Problem Description:
# A spanning tree of a graph can be defined as a graph with minimal set of edges that connect all vertices. A minimum spanning tree of a graph is a spanning tree of the graph with least weight (where the weight is computed by adding the weights of all the edges in the spanning tree). In general, a graph can have multiple minimum spanning trees. The problem is to find a minimum spanning tree of a graph.

# %% [markdown]
# This implementation uses a dictionary to represent the weighted graph, where the vertices are keys, and the values are dictionaries containing their adjacent vertices and their weights.
#
# Please note that this implementation assumes that the input graph is connected and weighted.
#
# First, let's create a simple graph to demonstrate Prim's algorithm:

# %%
graph = {
    "A": {"B": 10, "C": 15, "D": 20},
    "B": {"A": 10, "C": 12},
    "C": {"A": 15, "B": 12, "D": 18},
    "D": {"A": 20, "C": 18},
}

# %% [markdown]
# Now, let's implement Prim's algorithm:

# %%
def prim_algorithm(graph):
    min_tree = {}
    visited = set()
    min_tree[list(graph.keys())[0]] = []
    min_weight = 0

    while len(visited) < len(graph):
        min_edge = float('inf')
        next_vertex = None
        for vertex in min_tree:
            for adj_vertex, weight in graph[vertex].items():
                if adj_vertex not in visited:
                    if weight < min_edge:
                        min_edge = weight
                        next_vertex = adj_vertex

        min_tree[next_vertex] = []
        visited.add(next_vertex)
        min_weight += min_edge

    return min_tree, min_weight

# %% [markdown]
# Now, let's run the Prim's algorithm on the example graph:
# Keep in mind that this example uses a simple representation of a graph, but for more complex cases, you might want to use a library such as NetworkX to represent and manipulate graphs.

# %%
mst, min_weight = prim_algorithm(graph)
print("Minimum Spanning Tree: ", mst)
print("Minimum Weight: ", min_weight)
# Out:
# Minimum Spanning Tree:  {'A': [], 'B': [], 'C': [], 'D': []}
# Minimum Weight:  50

# %% [markdown]
# Take Differnt example of input graph as discussed in lecture slide and use above code to verify the output

# %%
graph = {
    "X": {"Y": 8, "Z": 5},
    "Y": {"X": 8, "Z": 10, "W": 2},
    "Z": {"X": 5, "Y": 10, "W": 6},
    "W": {"Y": 2, "Z": 6}
}

prims(graph)
# Out:
# Edge X-Z weight 5
# Edge Z-W weight 6
# Edge W-Y weight 2

# %% [markdown]
# Use same apporach for Kruskal's algorithm

# %%
graph = {
    "X": {"Y": 8, "Z": 5},
    "Y": {"X": 8, "Z": 10, "W": 2},
    "Z": {"X": 5, "Y": 10, "W": 6},
    "W": {"Y": 2, "Z": 6}
}

# %%
def prim_algorithm(graph):
    start = list(graph.keys())[0]
    visited = {start}
    mst_edges = []
    total_weight = 0

    while len(visited) < len(graph):
        min_edge = float('inf')
        u = v = None
        for node in visited:
            for neighbor, weight in graph[node].items():
                if neighbor not in visited and weight < min_edge:
                    min_edge = weight
                    u, v = node, neighbor
        mst_edges.append((u, v, min_edge))
        visited.add(v)
        total_weight += min_edge

    return mst_edges, total_weight

# %%
mst, min_weight = prim_algorithm(graph)
print("Minimum Spanning Tree: ", mst)
print("Minimum Weight: ", min_weight)
# Out:
# Minimum Spanning Tree:  [('X', 'Z', 5), ('Z', 'W', 6), ('W', 'Y', 2)]
# Minimum Weight:  13

# %%
def kruskal(graph):
    edges = []
    for u in graph:
        for v, w in graph[u].items():
            if (v, u, w) not in edges:
                edges.append((u, v, w))
    edges.sort(key=lambda x: x[2])
    parent = {node: node for node in graph}

    def find(x):
        while parent[x] != x:
            parent[x] = parent[parent[x]]
            x = parent[x]
        return x
    def union(x, y):
        parent[find(x)] = find(y)
    mst = []
    total = 0
    for u, v, w in edges:
        if find(u) != find(v):
            union(u, v)
            mst.append((u, v, w))
            total += w

    return mst, total

# %%
graph = {
    "X": {"Y": 8, "Z": 5},
    "Y": {"X": 8, "Z": 10, "W": 2},
    "Z": {"X": 5, "Y": 10, "W": 6},
    "W": {"Y": 2, "Z": 6}
}

mst, weight = kruskal(graph)
print("MST edges:", mst)
print("Total weight:", weight)
# Out:
# MST edges: [('Y', 'W', 2), ('X', 'Z', 5), ('Z', 'W', 6)]
# Total weight: 13

# %%
def find(parent, i):
    while parent[i] != i:
        i = parent[i]
    return i

def union(parent, u, v):
    parent[find(parent, u)] = find(parent, v)

def kruskal(graph):
    n = len(graph)
    edges = [(graph[i][j], i, j) for i in range(n) for j in range(i+1, n) if graph[i][j]]
    edges.sort()  # sort edges by weight

    parent = list(range(n))
    mst = []
    total_weight = 0

    for w, u, v in edges:
        if find(parent, u) != find(parent, v):
            union(parent, u, v)
            mst.append((u, v, w))
            total_weight += w

    for u, v, w in mst:
        print(f"Edge {u}-{v} weight {w}")
    print(f"Total weight of MST: {total_weight}")

# Example graph
graph = [
    [0, 8, 5, 0],
    [8, 0, 10, 2],
    [5, 10, 0, 6],
    [0, 2, 6, 0]
]

kruskal(graph)
# Out:
# Edge 1-3 weight 2
# Edge 0-2 weight 5
# Edge 2-3 weight 6
# Total weight of MST: 13
